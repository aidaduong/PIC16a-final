# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('products.csv')

# %%
df
# Out:
#                                                   url  \
# 0   https://www.yesstyle.com/en/im-from-rice-whip-...
# 1   https://www.yesstyle.com/en/by-wishtrend-green...
# 2   https://www.yesstyle.com/en/skin-1004-madagasc...
# 3   https://www.yesstyle.com/en/skin-1004-madagasc...
# 4   https://www.yesstyle.com/en/anua-heartleaf-que...
# 5   https://www.yesstyle.com/en/mixsoon-9-step-ski...
# 6   https://www.yesstyle.com/en/skin-1004-madagasc...
# 7   https://www.yesstyle.com/en/anua-heartleaf-por...
# 8   https://www.yesstyle.com/en/round-lab-1025-dok...
# 9   https://www.yesstyle.com/en/skin-1004-madagasc...
# 10  https://www.yesstyle.com/en/mixsoon-centella-c...
# 11  https://www.yesstyle.com/en/cosrx-low-ph-good-...
# 12  https://www.yesstyle.com/en/mixsoon-bean-clean...
# 13  https://www.yesstyle.com/en/skin-1004-madagasc...
# 14  https://www.yesstyle.com/en/haruharu-wonder-bl...
# 15  https://www.yesstyle.com/en/haruharu-wonder-bl...
# ...
