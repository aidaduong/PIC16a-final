# %%
import pandas as pd
import numpy as np

# %%
df3 = pd.read_csv('products1.csv')
df3
# Out:
#                                                   url  \
# 0   https://www.stylevana.com/en_US/purito-seoul-d...
# 1   https://www.stylevana.com/en_US/skin1004-madag...
# 2   https://www.stylevana.com/en_US/beauty-of-jose...
# 3   https://www.stylevana.com/en_US/rohto-menthola...
# 4   https://www.stylevana.com/en_US/isntree-hyalur...
# 5   https://www.stylevana.com/en_US/kao-biore-uv-a...
# 6   https://www.stylevana.com/en_US/round-lab-birc...
# 7   https://www.stylevana.com/en_US/haruharu-wonde...
# 8   https://www.stylevana.com/en_US/haruharu-wonde...
# 9   https://www.stylevana.com/en_US/skin1004-madag...
# 10  https://www.stylevana.com/en_US/beauty-of-jose...
# 11  https://www.stylevana.com/en_US/beauty-of-jose...
#
#                                                 image  \
# 0   https://sv9-cdn.stylevana.com/media/catalog/pr...
# 1   https://sv9-cdn.stylevana.com/media/catalog/pr...
# 2   https://sv9-cdn.stylevana.com/media/catalog/pr...
# ...

# %%
sunscreen = pd.read_csv('sunscreen.csv')
sunscreen['product'] = 'sunscreen'
sunscreen = sunscreen.rename(columns={'star': 'sv_star', 'num_reviews': 'sv_num_reviews'})
sunscreen
# Out:
#                                                   url  \
# 0   https://www.stylevana.com/en_US/beauty-of-jose...
# 1   https://www.stylevana.com/en_US/beauty-of-jose...
# 2   https://www.stylevana.com/en_US/bellflower-avo...
# 3   https://www.stylevana.com/en_US/goodal-green-t...
# 4   https://www.stylevana.com/en_US/abib-airy-suns...
# 5   https://www.stylevana.com/en_US/skin1004-madag...
# 6   https://www.stylevana.com/en_US/la-roche-posay...
# 7   https://www.stylevana.com/en_US/pyunkang-yul-a...
# 8   https://www.stylevana.com/en_US/shiseido-aness...
# 9   https://www.stylevana.com/en_US/isntree-hyalur...
# 10  https://www.stylevana.com/en_US/omi-sun-bears-...
# 11  https://www.stylevana.com/en_US/tocobo-bio-wat...
# 12  https://www.stylevana.com/en_US/purito-seoul-w...
# 13  https://www.stylevana.com/en_US/derma-b-everyd...
# 14  https://www.stylevana.com/en_US/canmake-mermai...
# 15  https://www.stylevana.com/en_US/house-of-hur-w...
# ...
