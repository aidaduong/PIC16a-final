# %%
import pandas as pd
import numpy as np

# %%
df2 = pd.read_csv('sunscreens.csv')
df2[df2['price'] == '$10.39']
# Out:
#                                                    url  \
# 299  https://www.stylevana.com/en_US/esfolio-3ha-cl...
#
#                                                  image  \
# 299  https://sv9-cdn.stylevana.com/media/catalog/pr...
#
#                                                   name   price
# 299  esfolio - 3HA Clear Cica Soothing Sun Stick SP...  $10.39

# %%
df2.head()
# Out:
#                                                  url  \
# 0  https://www.stylevana.com/en_US/beauty-of-jose...
# 1  https://www.stylevana.com/en_US/beauty-of-jose...
# 2  https://www.stylevana.com/en_US/beauty-of-jose...
# 3  https://www.stylevana.com/en_US/skin1004-madag...
# 4  https://www.stylevana.com/en_US/haruharu-wonde...
#
#                                                image  \
# 0  https://sv9-cdn.stylevana.com/media/catalog/pr...
# 1  https://sv9-cdn.stylevana.com/media/catalog/pr...
# 2  https://sv9-cdn.stylevana.com/media/catalog/pr...
# 3  https://sv9-cdn.stylevana.com/media/catalog/pr...
# 4  https://sv9-cdn.stylevana.com/media/catalog/pr...
#
#                                                 name   price
# 0  BEAUTY OF JOSEON - Relief Sun : Rice + Probiot...  $35.15
# 1  BEAUTY OF JOSEON - Relief Sun : Rice + Probiot...  $17.58
# 2  BEAUTY OF JOSEON - Relief Sun Aqua-fresh Rice ...  $17.58
# 3  SKIN1004 - Madagascar Centella Hyalu-Cica Wate...  $13.02
# ...

# %%
df3 = pd.read_csv('products.csv')
df3
# Out:
#                                                   url  \
# 0   https://www.stylevana.com/en_US/beauty-of-jose...
# 1   https://www.stylevana.com/en_US/skin1004-madag...
# 2   https://www.stylevana.com/en_US/purito-seoul-d...
# 3   https://www.stylevana.com/en_US/rohto-menthola...
# 4   https://www.stylevana.com/en_US/isntree-hyalur...
# 5   https://www.stylevana.com/en_US/round-lab-birc...
# 6   https://www.stylevana.com/en_US/kao-biore-uv-a...
# 7   https://www.stylevana.com/en_US/haruharu-wonde...
# 8   https://www.stylevana.com/en_US/haruharu-wonde...
# 9   https://www.stylevana.com/en_US/skin1004-madag...
# 10  https://www.stylevana.com/en_US/beauty-of-jose...
# 11  https://www.stylevana.com/en_US/beauty-of-jose...
#
#                                                 image  \
# 0   https://sv9-cdn.stylevana.com/media/catalog/pr...
# 1   https://sv9-cdn.stylevana.com/media/catalog/pr...
# 2   https://sv9-cdn.stylevana.com/media/catalog/pr...
# ...
